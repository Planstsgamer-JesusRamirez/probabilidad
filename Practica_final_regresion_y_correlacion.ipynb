# %%
# Importacion de librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression

# Carga de datos
df1 = pd.read_csv("grupo1.csv")
df2 = pd.read_csv("grupo2.csv")
df3 = pd.read_csv("grupo3.csv")

# Asignación de nombres a los grupos
df1.nombre_grupo = "Grupo 1"
df2.nombre_grupo = "Grupo 2"
df3.nombre_grupo = "Grupo 3"

#Histogramas de los 3 grupos de calificaciones
plt.figure(figsize=(10, 6))

plt.subplot(1, 3, 1)
sns.histplot(df1['Calificacion'], bins=10, kde=True)
plt.title('Histograma de Calificaciones - Grupo 1')
plt.xlabel('Calificación Final')
plt.ylabel('Frecuencia')

plt.subplot(1, 3, 2)
sns.histplot(df2['Calificacion'], bins=10, kde=True)
plt.title('Histograma de Calificaciones - Grupo 2')
plt.xlabel('Calificación Final')
plt.ylabel('Frecuencia')

plt.subplot(1, 3, 3)
sns.histplot(df3['Calificacion'], bins=10, kde=True)
plt.title('Histograma de Calificaciones - Grupo 3')
plt.xlabel('Calificación Final')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# Exploración de datos
def analizar_grupo(datos):
    print(f"\nExploración de datos - {datos.nombre_grupo}")
    print("-----------------------------------------")
    print(datos.describe())
    datos.hist(figsize=(10, 6))
    plt.show()

analizar_grupo(df1)
analizar_grupo(df2)
analizar_grupo(df3)

# Modelo de regresión lineal
def analizar_grupo(df, grupo):
    X = df[['HorasEstudio']]
    y = df['Calificacion']

    # Creacion y entrenar el modelo de regresión lineal
    reg = LinearRegression()
    reg.fit(X, y)

    # Obtener el producto o producto e intercepto de la regresion
    pendiente = reg.coef_[0]
    intercepto = reg.intercept_

    # Calcular el coeficiente de correlación de Pearson
    correlacion, _ = pearsonr(df['HorasEstudio'], df['Calificacion'])

    # Resultados
    print(f"Grupo {grupo}")
    print(f"Pendiente: {pendiente}")
    print(f"Intercepto: {intercepto}")
    print(f"Coeficiente de correlación de Pearson: {correlacion}\n")

    # Crear gráfica de dispersión con línea de regresión
    plt.figure(figsize=(11, 6))
    sns.scatterplot(x='HorasEstudio', y='Calificacion', data=df)
    plt.plot(df['HorasEstudio'], reg.predict(X), color='green')
    plt.title(f'Regresión Lineal - Grupo {grupo}')
    plt.xlabel('Horas de Estudio')
    plt.ylabel('Calificación Final')
    plt.show()

# Esto para visualizar el grupo y resultados de cada uno
analizar_grupo(df1, 1)
analizar_grupo(df2, 2)
analizar_grupo(df3, 3)
# Out:
# Exploración de datos - Grupo 1
# -----------------------------------------
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000
# Exploración de datos - Grupo 2
# -----------------------------------------
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.912000
# std        4.219174     20.668922
# min        3.790000     26.100000
# 25%       12.032500     63.500000
# 50%       14.600000     78.550000
# 75%       17.715000     93.300000
# max       20.000000     99.000000
# Exploración de datos - Grupo 3
# -----------------------------------------
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# ...

# %% [markdown]
# ## Preguntas
# //1. ¿¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la
# relación entre el tiempo de estudio y las calificaciones finales? R= Aunque el primero sea negativo y no halla tanto incremento en el primer grupo, dice que en los otros 2 grupos, con pocos adiciones de horas en el estudio incrementa mejor la califacion positiva para coeficiente de los grupos.
#
# //2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y
# dirección de la relación entre las variables? R= El coeficiente de correlación indica la fuerza y dirección de la relación entre las variables. Si es positivo, las variables aumentan o disminuyen juntas; si es negativo, cuando unas aumentan, las otras disminuyen. Su valor absoluto entre 0 y 1 refleja la fuerza: cerca de 1 significa relación fuerte, cerca de 0 significa relación débil.
#
# //3.¿El modelo de regresión lineal es estadísticamente significativo? R= Claro que es significativo, no solo por predecir los valores de las variables sino que tambien sirve para las empresas trabajando en su sistema software y tambien para convertir datos sin procesar de manera confiable y predecible en inteligencia empresarial y conocimiento práctico.
#
# //4.¿Qué tan confiable es el modelo de regresión para predecir las
# calificaciones finales de los estudiantes basado en el tiempo de estudio? R= Ya depende de su resultante R2, ya si este es cercano a 1 o 2 es de alta confiabilidad, ya sea que es cercano a 0 pues indicara baja confiabilidad; ya ahi se consideran unas variables del modelo del programa adicionales mas.
#
# Esta ultima pregunta me apoye con unas paginas de internet para buscar respuesta de esta ultima.
